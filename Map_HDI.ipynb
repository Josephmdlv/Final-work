# %% [markdown]
# <a href="https://colab.research.google.com/github/Josephmdlv/Final-work/blob/main/Map_HDI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import os
from google.colab import files

def download_and_process_data(url):
  filename = os.path.basename(url)
  response = requests.get(url)

  with open(filename, 'wb') as file:
      file.write(response.content)

  df = pd.read_csv(filename)

  return df


df = download_and_process_data("https://raw.githubusercontent.com/IkerZha0401/QM2_Final_PJ/refs/heads/main/MENA_HDI.csv")
df
# Out:
#                   Country Name   2000   2001   2002   2003   2004   2005  \
# 0                      Algeria  0.652  0.659  0.668  0.675  0.683  0.690
# 1                      Bahrain  0.775  0.786  0.792  0.799  0.795  0.791
# 2                     Djibouti  0.330  0.340  0.346  0.357  0.365  0.374
# 3                        Egypt  0.629  0.633  0.634  0.632  0.635  0.637
# 4   Iran (Islamic Republic of)  0.692  0.700  0.708  0.713  0.722  0.727
# 5                         Iraq  0.583  0.588  0.588  0.566  0.588  0.591
# 6                       Israel  0.835  0.838  0.843  0.843  0.847  0.856
# 7                       Jordan  0.681  0.687  0.691  0.697  0.707  0.713
# 8                       Kuwait  0.780  0.779  0.785  0.796  0.800  0.800
# 9                      Lebanon    NaN    NaN    NaN    NaN    NaN  0.710
# 10                       Libya  0.746  0.748  0.750  0.755  0.758  0.764
# 11                     Morocco  0.525  0.536  0.547  0.557  0.564  0.570
# ...

# %%
from typing import Tuple
import plotly.express as px
import plotly.graph_objects as go

df_long = df.melt(
    id_vars=['Country Name'],
    var_name='Year',
    value_name='HDI'
)

df_long['Year'] = pd.to_numeric(df_long['Year'], errors='coerce')
df_long['HDI']= pd.to_numeric(df_long['HDI'], errors='coerce')

fig = px.choropleth(
    df_long,
    locations='Country Name',
    locationmode='country names',
    color='HDI',
    animation_frame="Year",
    color_continuous_scale=px.colors.sequential.Greens,
    title="MENA Human Development Index 2000-2020",
    hover_name="Country Name",
    hover_data={"HDI": True, "Year": True}
)

fig.update_geos(
    visible=True,
    countrycolor="Black",
    showcoastlines=False,
    coastlinecolor="Black",
    fitbounds="locations"
)

arab_spring_countires = ["Egypt","Tunisia","Libya","Syria","Yemen","Bahrain"]

for country in arab_spring_countires:
    fig.add_trace(
        go.Choropleth(
            locations=[country],
            locationmode="country names",
            z=[0]*len(arab_spring_countries),
            colorscale=[[0,"rgba(0,0,0,0)"],[1,"rgba(0,0,0,0)"]],
            showscale=False,
            marker_line_color="black",
            marker_line_width=1.5,
            hoverinfo="skip"
        )
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
